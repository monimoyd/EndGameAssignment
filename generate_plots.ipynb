# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
eval_epoch_reward_df = pd.read_csv("results/eval_epoch_reward.csv")

# %%
eval_epoch_reward_df
# Out:
#       2  -619.0
# 0     4 -653.40
# 1     6 -665.15
# 2     8 -703.25
# 3    10 -725.85
# 4    12 -672.60
# ..  ...     ...
# 94  192 -440.10
# 95  194 -470.90
# 96  196 -469.90
# 97  198 -385.35
# 98  200 -515.15
#
# [99 rows x 2 columns]

# %%
eval_epoch_reward_df.columns=["episode", "total_reward"]

# %%
fig, axs = plt.subplots(figsize=(10,10))
axs.plot(eval_epoch_reward_df["episode"], eval_epoch_reward_df["total_reward"], label="Evaluation After Training Episode vs Avearge Total Rewards")
axs.legend()
plt.xlabel("Episode")
plt.ylabel("Average Total Rewards")
plt.show()

# %%
eval_on_road_stats_df = pd.read_csv("results/eval_on_road_stats.csv")

# %%
eval_on_road_stats_df.columns=['train_episode','eval_episode', 'on_road_count', 'off_road_count', 'hit_boundary_count', 'hit_goal_count']

# %%
eval_on_road_stats_df.head()
# Out:
#    train_episode  eval_episode  on_road_count  off_road_count  \
# 0              2             2            107             394
# 1              2             3             71             430
# 2              2             4             63             438
# 3              2             5            131             370
# 4              2             6            132             369
#
#    hit_boundary_count  hit_goal_count
# 0                   1               0
# 1                   3               0
# 2                   3               0
# 3                   1               0
# 4                   1               0

# %%
eval_on_road_stats_df["on_road_percentage"]=eval_on_road_stats_df["on_road_count"]/(eval_on_road_stats_df["on_road_count"] + eval_on_road_stats_df["off_road_count"])*100

# %%
eval_on_road_stats_df.head()
# Out:
#    train_episode  eval_episode  on_road_count  off_road_count  \
# 0              2             2            107             394
# 1              2             3             71             430
# 2              2             4             63             438
# 3              2             5            131             370
# 4              2             6            132             369
#
#    hit_boundary_count  hit_goal_count  on_road_percentage
# 0                   1               0           21.357285
# 1                   3               0           14.171657
# 2                   3               0           12.574850
# 3                   1               0           26.147705
# 4                   1               0           26.347305

# %%
eval_on_road_stats_filtered_df = eval_on_road_stats_df[["train_episode", "on_road_percentage", "hit_boundary_count", "hit_goal_count"]]

# %%
eval_on_road_stats_filtered_mean_df = eval_on_road_stats_filtered_df.groupby(['train_episode']).mean()

# %%
eval_on_road_stats_filtered_mean_df.head()
# Out:
#                on_road_percentage  hit_boundary_count  hit_goal_count
# train_episode
# 2                       21.357285            1.666667             0.0
# 4                       17.784431            1.700000             0.1
# 6                       18.243513            1.800000             0.0
# 8                       15.289421            2.100000             0.0
# 10                      13.852295            2.000000             0.0

# %%
fig, axs = plt.subplots(figsize=(10,10))
axs.plot(eval_on_road_stats_filtered_mean_df.index,eval_on_road_stats_filtered_mean_df["on_road_percentage"], label="Evaluation After Training Episode vs On Road Percentage")
axs.legend()
plt.xlabel("Episode")
plt.ylabel("On Road Percentage")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(10,10))
axs.plot(eval_on_road_stats_filtered_mean_df.index,eval_on_road_stats_filtered_mean_df["hit_boundary_count"], label="Evaluation After Training Episode vs Average Hit Boundary")
axs.legend()
plt.xlabel("Episode")
plt.ylabel("Average Hit Boundary")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(10,10))
axs.plot(eval_on_road_stats_filtered_mean_df.index,eval_on_road_stats_filtered_mean_df["hit_goal_count"], label="Evaluation After Training Episode vs Average Hit Goal")
axs.legend()
plt.xlabel("Episode")
plt.ylabel("Average Hit Goal")
plt.show()

# %%
train_epoch_reward_df = pd.read_csv("results/train_epoch_reward.csv")

# %%
train_epoch_reward_df.columns=["episode", "total_reward"]

# %%
fig, axs = plt.subplots(figsize=(10,10))
axs.plot(eval_epoch_reward_df["episode"], eval_epoch_reward_df["total_reward"], label="Training Episode vs Total Rewards")
axs.legend()
plt.xlabel("Episode")
plt.ylabel("Total Rewards")
plt.show()

# %%
train_on_road_stats_df = pd.read_csv("results/train_on_road_stats.csv")

# %%
train_on_road_stats_df.columns=['train_episode', 'on_road_count', 'off_road_count', 'hit_boundary_count', 'hit_goal_count']

# %%
train_on_road_stats_df["on_road_percentage"]=train_on_road_stats_df["on_road_count"]/(train_on_road_stats_df["on_road_count"] + eval_on_road_stats_df["off_road_count"])*100

# %%
train_on_road_stats_filtered_df = train_on_road_stats_df[["train_episode", "on_road_percentage", "hit_boundary_count", "hit_goal_count"]]

# %%
train_on_road_stats_filtered_mean_df = train_on_road_stats_filtered_df.groupby(['train_episode']).mean()

# %%
train_on_road_stats_filtered_mean_df.head()
# Out:
#                on_road_percentage  hit_boundary_count  hit_goal_count
# train_episode
# 1                       59.795918                   6               0
# 2                       48.748510                   7               0
# 3                       60.326087                   3               0
# 4                       50.134771                   7               0
# 5                       51.447368                   6               0

# %%
fig, axs = plt.subplots(figsize=(10,10))
axs.plot(train_on_road_stats_filtered_mean_df.index,train_on_road_stats_filtered_mean_df["on_road_percentage"], label="Evaluation After Training Episode vs On Road Percentage")
axs.legend()
plt.xlabel("Episode")
plt.ylabel("On Road Percentage")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(10,10))
axs.plot(train_on_road_stats_filtered_mean_df.index,train_on_road_stats_filtered_mean_df["hit_boundary_count"], label="Training Episode vs Hit Boundary Count")
axs.legend()
plt.xlabel("Episode")
plt.ylabel("Hit Boundary Count")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(10,10))
axs.plot(train_on_road_stats_filtered_mean_df.index,train_on_road_stats_filtered_mean_df["hit_goal_count"], label="Evaluation After Training Episode vs Average Hit Goal")
axs.legend()
plt.xlabel("Episode")
plt.ylabel("Hit Goal Count")
plt.show()
